# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.datasets import MultivariateAnomalyFunction
from src.datasets import SyntheticDataGenerator

# %%
for extreme_value in [0.125, 0.25, 0.5, 1, 2, 4, 8, 16]:
    X_train, y_train, X_test, y_test = SyntheticDataGenerator.get(
        'extreme_1_extremeness', seed=2432, extreme_value=extreme_value).data()
    plt.title(extreme_value)
    plt.plot(X_test, zorder=1)
    plt.scatter(X_test.index, X_test, 2, c=np.where(y_test == 1, 'red', 'blue'), zorder=2)
    plt.show()

# %%
for extreme_value in [0.125, 0.25, 0.5, 1, 2, 4, 8, 16]:
    X_train, y_train, X_test, y_test = SyntheticDataGenerator.get(
        'shift_1_extremeness', seed=2432, extreme_value=extreme_value).data()
    plt.title(extreme_value)
    plt.plot(X_test, zorder=1)
    plt.scatter(X_test.index, X_test, 2, c=np.where(y_test == 1, 'red', 'blue'), zorder=2)
    plt.show()

# %%
for extreme_value in [0.125, 0.25, 0.5, 1, 2, 4, 8, 16]:
    X_train, y_train, X_test, y_test = SyntheticDataGenerator.get(
        'variance_1_extremeness', seed=2432, extreme_value=extreme_value).data()
    plt.title(extreme_value)
    plt.plot(X_test, zorder=1)
    plt.scatter(X_test.index, X_test, 2, c=np.where(y_test == 1, 'red', 'blue'), zorder=2)
    plt.show()

# %%
for extreme_value in [0.125, 0.25, 0.5, 1, 2, 4, 8, 16]:
    X_train, y_train, X_test, y_test = SyntheticDataGenerator.get(
        'trend_1_extremeness', seed=2432, extreme_value=extreme_value).data()
    plt.title(extreme_value)
    plt.plot(X_test, zorder=1)
    plt.scatter(X_test.index, X_test, 2, c=np.where(y_test == 1, 'red', 'blue'), zorder=2)
    plt.show()
