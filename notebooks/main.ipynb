# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
from main import main
import logging
logging.getLogger().setLevel(logging.INFO)
# Out:
# /home/willi/Documents/MP-2018/venv_mp/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
main()
# Out:
# N/A% (0 of 4) |                          | Elapsed Time: 0:00:00 ETA:  --:--:--INFO:root:Training Recurrent EBM on Synthetic Extreme Outliers
# ...
# 100%|██████████| 15/15 [00:06<00:00,  2.49it/s]
#  25% (1 of 4) |######                    | Elapsed Time: 0:00:07 ETA:   0:00:22INFO:root:Training LSTM-AD on Synthetic Extreme Outliers
#  50% (2 of 4) |#############             | Elapsed Time: 0:02:07 ETA:   0:03:59INFO:root:Training Donut on Synthetic Extreme Outliers
#   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:tensorflow:Restoring parameters from /tmp/tmpk38j19wh/variables.dat-1200
# INFO:tensorflow:Restoring parameters from /tmp/tmpk38j19wh/variables.dat-1200
# 100%|██████████| 1/1 [00:09<00:00,  9.94s/it]
#  75% (3 of 4) |###################       | Elapsed Time: 0:02:19 ETA:   0:00:12INFO:root:Training DAGMM on Synthetic Extreme Outliers
# /home/willi/Documents/MP-2018/venv_mp/lib/python3.6/site-packages/numpy/linalg/linalg.py:1874: RuntimeWarning: invalid value encountered in det
# ...
