# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
from main import main
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
main()
# Out:
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]    | Elapsed Time: 0:01:10 ETA:   0:02:10
# INFO:tensorflow:Restoring parameters from /tmp/tmpt3qirb9_/variables.dat-100
# INFO:tensorflow:Restoring parameters from /tmp/tmpt3qirb9_/variables.dat-100
#  25%|██▌       | 1/4 [00:05<00:17,  5.81s/it]
# INFO:tensorflow:Restoring parameters from /tmp/tmpu3cyl22x/variables.dat-500
# INFO:tensorflow:Restoring parameters from /tmp/tmpu3cyl22x/variables.dat-500
#  50%|█████     | 2/4 [00:13<00:13,  6.68s/it]
# INFO:tensorflow:Restoring parameters from /tmp/tmpqfq499pt/variables.dat-500
# INFO:tensorflow:Restoring parameters from /tmp/tmpqfq499pt/variables.dat-500
#  75%|███████▌  | 3/4 [00:21<00:07,  7.26s/it]
# INFO:tensorflow:Restoring parameters from /tmp/tmp5vxlfu20/variables.dat-500
# INFO:tensorflow:Restoring parameters from /tmp/tmp5vxlfu20/variables.dat-500
# 100%|██████████| 4/4 [00:29<00:00,  7.34s/it]
# 100% (4 of 4) |##########################| Elapsed Time: 0:01:49 Time:  0:01:49
# ...
